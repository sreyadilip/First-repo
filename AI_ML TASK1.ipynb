# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('dark_background')

# %%
df=pd.read_csv('/content/moviegenre.csv')

# %%
df.head()
# Out:
#              Title  Year  Director  Duration  Rating   Votes  \
# 0  Winds of Fate 4  1980    R. Lee       167     4.1  182425
# 1     Firestorm 11  2014   S. Chen       166     4.1  449351
# 2    Silent Echo 2  2016   A. Khan       170     4.1  363328
# 3    City Lights 4  1982  L. Zhang       170     9.9   62371
# 4   Broken Truth 1  1990  L. Zhang        91     5.3    4600
#
#                                          Description  Language Country  \
# 0   A touching love story with heartwarming moments.   Spanish   China
# 1  A fast-paced thriller with intense action scenes.    Korean   China
# 2  A fast-paced thriller with intense action scenes.    Korean   Japan
# 3  An emotional journey exploring complex charact...  Japanese   Japan
# 4  An imaginative world filled with magic and won...    Korean     USA
#
#    Budget_USD  BoxOffice_USD    Genre Production_Company Content_Rating  \
# 0    39979615      179936008  Romance         DreamWorks              R
# ...

# %%
df.tail()
# Out:
#                  Title  Year    Director  Duration  Rating   Votes  \
# 49995    Ocean Call 20  2013  T. Johnson       149     6.8  340904
# 49996    Ocean Call 13  2001    M. Brown       166     7.6  214228
# 49997  Last Mission 15  2017    J. Smith       158     9.2  251931
# 49998     Firestorm 11  1992    J. Smith       166     7.2  487956
# 49999   Silent Echo 12  2009    P. Adams       117     4.3  392762
#
#                                              Description  Language  \
# 49995   A touching love story with heartwarming moments.   English
# 49996  A spine-chilling tale that evokes fear and dread.  Japanese
# 49997   A light-hearted comedy that guarantees laughter.    Korean
# 49998  A spine-chilling tale that evokes fear and dread.  Mandarin
# 49999  An imaginative world filled with magic and won...   Spanish
#
#            Country  Budget_USD  BoxOffice_USD    Genre  Production_Company  \
# 49995           UK    62456512        3291117  Romance      Yash Raj Films
# ...

# %%
df.describe()
# Out:
#                Year     Duration        Rating          Votes    Budget_USD  \
# count  50000.000000  50000.00000  50000.000000   50000.000000  5.000000e+04
# mean    2001.562620    130.07312      6.926472  249699.050540  9.179143e+07
# std       12.722539     29.11097      1.698758  144314.043032  5.823888e+07
# min     1980.000000     80.00000      4.000000     516.000000  1.135566e+06
# 25%     1991.000000    105.00000      5.500000  124531.500000  4.389040e+07
# 50%     2002.000000    130.00000      6.900000  248582.000000  8.062480e+07
# 75%     2013.000000    155.00000      8.400000  374833.500000  1.475557e+08
# max     2023.000000    180.00000      9.900000  499984.000000  1.984445e+08
#
#        BoxOffice_USD    Num_Awards  Critic_Reviews
# count   5.000000e+04  50000.000000    50000.000000
# mean    5.176063e+08      9.964440      500.176380
# std     2.880283e+08      6.066303      289.971792
# min     3.291117e+06      0.000000        0.000000
# ...

# %%
df.shape
# Out:
# (50000, 17)

# %%
df.columns
# Out:
# Index(['Title', 'Year', 'Director', 'Duration', 'Rating', 'Votes',
#        'Description', 'Language', 'Country', 'Budget_USD', 'BoxOffice_USD',
#        'Genre', 'Production_Company', 'Content_Rating', 'Lead_Actor',
#        'Num_Awards', 'Critic_Reviews'],
#       dtype='object')

# %%
df.nunique()
# Out:
# Title                   260
# Year                     44
# Director                 10
# Duration                101
# Rating                   60
# Votes                 47579
# Description               7
# Language                  7
# Country                   7
# Budget_USD              100
# BoxOffice_USD           100
# Genre                     7
# Production_Company       10
# Content_Rating            5
# Lead_Actor               10
# Num_Awards               21
# Critic_Reviews         1001
# dtype: int64

# %%
df['Duration'].unique()
# Out:
# array([167, 166, 170,  91, 116, 117, 111, 129, 169, 112, 135,  96, 168,
#        123, 162,  89, 179, 155,  86, 151,  82, 154, 127, 145, 165, 128,
#        133, 160, 131, 104, 172, 159, 107, 176, 140,  80, 102, 125, 146,
#         83, 161,  88, 173, 118,  95,  98, 142, 101, 138, 139, 103, 147,
#         87, 158,  97, 109, 134, 156, 124,  90, 150, 108, 163, 120,  94,
#        105, 144, 149, 119, 180, 148, 115,  81, 113, 143, 100, 126,  92,
#         85, 175, 153, 157, 114, 171, 177, 106, 164,  84, 132, 152,  99,
#         93, 136, 130, 122, 110, 141, 174, 178, 121, 137])

# %%
df.isnull()
# Out:
#        Title   Year  Director  Duration  Rating  Votes  Description  Language  \
# 0      False  False     False     False   False  False        False     False
# 1      False  False     False     False   False  False        False     False
# 2      False  False     False     False   False  False        False     False
# 3      False  False     False     False   False  False        False     False
# 4      False  False     False     False   False  False        False     False
# ...      ...    ...       ...       ...     ...    ...          ...       ...
# 49995  False  False     False     False   False  False        False     False
# 49996  False  False     False     False   False  False        False     False
# 49997  False  False     False     False   False  False        False     False
# 49998  False  False     False     False   False  False        False     False
# 49999  False  False     False     False   False  False        False     False
#
# ...

# %%
df.drop(['Director','Description'],axis=1)
# Out:
#                  Title  Year  Duration  Rating   Votes  Language      Country  \
# 0      Winds of Fate 4  1980       167     4.1  182425   Spanish        China
# 1         Firestorm 11  2014       166     4.1  449351    Korean        China
# 2        Silent Echo 2  2016       170     4.1  363328    Korean        Japan
# 3        City Lights 4  1982       170     9.9   62371  Japanese        Japan
# 4       Broken Truth 1  1990        91     5.3    4600    Korean          USA
# ...                ...   ...       ...     ...     ...       ...          ...
# 49995    Ocean Call 20  2013       149     6.8  340904   English           UK
# 49996    Ocean Call 13  2001       166     7.6  214228  Japanese  South Korea
# 49997  Last Mission 15  2017       158     9.2  251931    Korean  South Korea
# 49998     Firestorm 11  1992       166     7.2  487956  Mandarin  South Korea
# 49999   Silent Echo 12  2009       117     4.3  392762   Spanish       France
#
# ...

# %%
a=df.select_dtypes(include=np.number)
a
# Out:
#        Year  Duration  Rating   Votes  Budget_USD  BoxOffice_USD  Num_Awards  \
# 0      1980       167     4.1  182425    39979615      179936008           8
# 1      2014       166     4.1  449351   116404774      802121619          20
# 2      2016       170     4.1  363328   166261330      225526871          16
# 3      1982       170     9.9   62371    28861315       69813738          15
# 4      1990        91     5.3    4600    43890403      375136716           6
# ...     ...       ...     ...     ...         ...            ...         ...
# 49995  2013       149     6.8  340904    62456512        3291117          18
# 49996  2001       166     7.6  214228    33239921      465759764           3
# 49997  2017       158     9.2  251931    79589169      820566917           1
# 49998  1992       166     7.2  487956   179834680      131779818          10
# 49999  2009       117     4.3  392762    45434366      957562425          20
#
#        Critic_Reviews
# ...

# %%
a.corr()
# Out:
#                     Year  Duration    Rating     Votes  Budget_USD  \
# Year            1.000000  0.004646  0.000992 -0.008429   -0.005187
# Duration        0.004646  1.000000  0.002120 -0.000909   -0.002075
# Rating          0.000992  0.002120  1.000000  0.001076    0.003384
# Votes          -0.008429 -0.000909  0.001076  1.000000    0.001128
# Budget_USD     -0.005187 -0.002075  0.003384  0.001128    1.000000
# BoxOffice_USD  -0.001177 -0.007254 -0.005795 -0.004112    0.000965
# Num_Awards     -0.006465 -0.000770  0.009573  0.007686   -0.001992
# Critic_Reviews  0.004526  0.000291  0.000546 -0.001974    0.003938
#
#                 BoxOffice_USD  Num_Awards  Critic_Reviews
# Year                -0.001177   -0.006465        0.004526
# Duration            -0.007254   -0.000770        0.000291
# Rating              -0.005795    0.009573        0.000546
# Votes               -0.004112    0.007686       -0.001974
# Budget_USD           0.000965   -0.001992        0.003938
# ...

# %%
import seaborn as sns
sns.pairplot(data=a)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
plt.figure(figsize=(10,10))
sns.heatmap(a.corr(),annot=True)
# Out:
# <Axes: >

# %%
plt.xticks(np.arange(1,10,0.5))
plt.yticks(np.arange(0,50000,10000))
plt.scatter(df['Rating'],df['Votes'])
plt.title('Rating vs Votes')
plt.xlabel('Rating')
plt.ylabel('Votes')
plt.show()

# %%
sns.distplot(df['Rating'],bins=5)
# Out:
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
sns.relplot(x='Rating', y='Votes', hue='Genre', data=df)

# %%
sns.catplot(x='Rating', y='Votes',kind='box',data=df)

# %%
b=df.iloc[0:10,1:11]
b
# Out:
#    Year    Director  Duration  Rating   Votes  \
# 0  1980      R. Lee       167     4.1  182425
# 1  2014     S. Chen       166     4.1  449351
# 2  2016     A. Khan       170     4.1  363328
# 3  1982    L. Zhang       170     9.9   62371
# 4  1990    L. Zhang        91     5.3    4600
# 5  1985    D. Patel       116     4.4  268620
# 6  2004      R. Lee       117     5.3   38970
# 7  2016  T. Johnson       111     5.5   86559
# 8  1982    L. Zhang       129     4.3  288173
# 9  1993     S. Chen       169     7.5  355096
#
#                                          Description  Language Country  \
# 0   A touching love story with heartwarming moments.   Spanish   China
# 1  A fast-paced thriller with intense action scenes.    Korean   China
# 2  A fast-paced thriller with intense action scenes.    Korean   Japan
# 3  An emotional journey exploring complex charact...  Japanese   Japan
# 4  An imaginative world filled with magic and won...    Korean     USA
# ...

# %%
plt.pie(b['Rating'],labels=b['Language'],autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7ea65d59d4d0>,
# ...
#  [Text(1.069421608094722, 0.2575605251976689, 'Spanish'),
#   Text(0.8349003263951204, 0.7161993053510466, 'Korean'),
#   Text(0.41728769784309216, 1.0177774694051802, 'Korean'),
#   Text(-0.44644486143327955, 1.0053292921723807, 'Japanese'),
#   Text(-1.0581612095076247, 0.3004910226501965, 'Korean'),
#   Text(-1.056411335666598, -0.30658618669978305, 'English'),
#   Text(-0.7328965959314266, -0.82028201228122, 'Spanish'),
#   Text(-0.11708267361979227, -1.0937511817310377, 'English'),
#   Text(0.4866366131452094, -0.98650129586664, 'French'),
#   Text(0.9987914113982137, -0.4608857955254907, 'Hindi')],
#  [Text(0.5833208771425756, 0.1404875591987285, '7.5%'),
#   Text(0.455400178033702, 0.39065416655511626, '7.5%'),
#   Text(0.2276114715507775, 0.5551513469482801, '7.5%'),
#   Text(-0.243515378963607, 0.5483614320940258, '18.2%'),
#   Text(-0.5771788415496134, 0.16390419417283444, '9.7%'),
# ...

# %%
plt.figure(figsize=(8,8))
plt.subplot(2,2,1)
sns.barplot(x='Rating',y='Votes',data=df)
plt.subplot(2,2,2)
sns.scatterplot(x='Rating',y='Votes',data=df)
plt.subplot(2,2,3)
plt.pie(b['Rating'],labels=b['Language'],autopct='%1.1f%%',radius=1.0)
plt.subplot(2,2,4)
plt.plot(b['Rating'],b['Country'],'g-')
plt.plot(b['Rating'],b['Country'],'ro')
plt.show()

# %%
plt.savefig('/content/subplot',facecolor='k')
